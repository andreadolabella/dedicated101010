# %% [markdown]
# # Análise do risco de inadimplência dos mutuários
#
# Seu projeto é preparar um relatório para a divisão de empréstimos de um banco. Você precisará descobrir se o estado civil de um cliente e o número de filhos têm impacto sobre se ele deixará de pagar um empréstimo. O banco já tem alguns dados sobre a capacidade de crédito dos clientes.
#
# Seu relatório será considerado ao construir a **pontuação de crédito** de um cliente em potencial. A **pontuação de crédito** é usada para avaliar a capacidade de um devedor em potencial de pagar seu empréstimo.
#
# Esse projeto tem como objetivo a elaboração de relatório de risco para a divisão de emprestimos de um banco, demonstrando os impactos de fatores como estado civil e número de de filhos, por exemplo, quando falamos de inadimplência. Deverá ser construído indicador chamado **pontuação de crédito**, que será usado para avaliação do cliente acerca da capacidade de pagamento dos devedores.

# %%
import pandas as pd

cse = pd.read_csv('/datasets/credit_scoring_eng.csv')

# %%
cse
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1   -8437.673028         42    bachelor's degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 4             0  340266.072047         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1   -4529.316663         43  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F    business     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#        total_income                  purpose
# 0         40620.102    purchase of the house
# 1         17932.802             car purchase
# 2         23341.752    purchase of the house
# 3         42820.568  supplementary education
# 4         25378.572        to have a wedding
# ...             ...                      ...
# 21520     35966.698     housing transactions
# 21521     24959.969        purchase of a car
# 21522     14347.610                 property
# 21523     39054.888        buying my own car
# 21524     13127.587             to buy a car
#
# [21525 rows x 12 columns]

# %% [markdown]
# ## Tarefa 1. Exploração de dados
#
# **Descrição dos dados**
# - `children` - o número de crianças na família
# - `days_employed` - experiência de trabalho em dias
# - `dob_years` - idade do cliente em anos
# - `education` - educação do cliente
# - `education_id` - identificador de educação
# - `family_status` - estado civil do cliente
# - `family_status_id` - identificador de estado civil
# - `gender` - gênero do cliente
# - `income_type` - tipo de emprego
# - `debt` - havia alguma dívida no pagamento do empréstimo
# - `total_income` - renda mensal
# - `purpose` - o objetivo de obter um empréstimo

# %%
cse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
cse.head(10)
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42    bachelor's degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
# 5         0    -926.185831         27    bachelor's degree             0
# 6         0   -2879.202052         43    bachelor's degree             0
# 7         0    -152.779569         50  SECONDARY EDUCATION             1
# 8         2   -6929.865299         35    BACHELOR'S DEGREE             0
# 9         0   -2188.756445         41  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
# 5  civil partnership                 1      M    business     0     40922.170
# 6            married                 0      F    business     0     38484.156
# 7            married                 0      M    employee     0     21731.829
# 8  civil partnership                 1      F    employee     0     15337.093
# 9            married                 0      M    employee     0     23108.150
#
#                                purpose
# 0                purchase of the house
# 1                         car purchase
# 2                purchase of the house
# 3              supplementary education
# 4                    to have a wedding
# 5                purchase of the house
# 6                 housing transactions
# 7                            education
# 8                     having a wedding
# 9  purchase of the house for my family

# %% [markdown]
# O arquivo de dados tem 21525 linhas e 12 colunas, tendo sido evidenciada a presença de duas colunas com cerca de 10% dados igualmente em ambas, **days_employed** e **total_income** . Existem também valores negativos e distorcidos. Serão feitas análise e correção das distorções identificadas.

# %%
cse.describe()
# Out:
#            children  days_employed     dob_years  education_id  \
# count  21525.000000   19351.000000  21525.000000  21525.000000
# mean       0.538908   63046.497661     43.293380      0.817236
# std        1.381587  140827.311974     12.574584      0.548138
# min       -1.000000  -18388.949901      0.000000      0.000000
# 25%        0.000000   -2747.423625     33.000000      1.000000
# 50%        0.000000   -1203.369529     42.000000      1.000000
# 75%        1.000000    -291.095954     53.000000      1.000000
# max       20.000000  401755.400475     75.000000      4.000000
#
#        family_status_id          debt   total_income
# count      21525.000000  21525.000000   19351.000000
# mean           0.972544      0.080883   26787.568355
# std            1.420324      0.272661   16475.450632
# min            0.000000      0.000000    3306.762000
# 25%            0.000000      0.000000   16488.504500
# 50%            0.000000      0.000000   23202.870000
# 75%            1.000000      0.000000   32549.611000
# max            4.000000      1.000000  362496.645000

# %% [markdown]
# Só constam valores ausentes nas colunas 'days_employed' e 'total_income', as demais não. Será necessário fazer análises e comparações entre essas colunas e as que não apresentam valores ausentes para criar hipóteses e posterior correção dos mesmos.
#
# Antes de tratar os valores ausentes, será feita analise e correção dos dados duplicados existentes.

# %%
cse.duplicated().sum()
# Out:
# 54

# %%
cse = cse.drop_duplicates()

# %%
cse.duplicated().sum()
# Out:
# 0

# %%
cse[cse['days_employed'].isna()]
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 12            0            NaN         65  secondary education             1
# 26            0            NaN         41  secondary education             1
# 29            0            NaN         63  secondary education             1
# 41            0            NaN         50  secondary education             1
# 55            0            NaN         54  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21489         2            NaN         47  Secondary Education             1
# 21495         1            NaN         50  secondary education             1
# 21497         0            NaN         48    BACHELOR'S DEGREE             0
# 21502         1            NaN         42  secondary education             1
# 21510         2            NaN         28  secondary education             1
#
#            family_status  family_status_id gender    income_type  debt  \
# 12     civil partnership                 1      M        retiree     0
# 26               married                 0      M  civil servant     0
# 29             unmarried                 4      F        retiree     0
# 41               married                 0      F  civil servant     0
# 55     civil partnership                 1      F        retiree     1
# ...                  ...               ...    ...            ...   ...
# 21489            married                 0      M       business     0
# 21495  civil partnership                 1      F       employee     0
# 21497            married                 0      F       business     0
# 21502            married                 0      F       employee     0
# 21510            married                 0      F       employee     0
#
#        total_income                   purpose
# 12              NaN         to have a wedding
# 26              NaN                 education
# 29              NaN    building a real estate
# 41              NaN  second-hand car purchase
# 55              NaN         to have a wedding
# ...             ...                       ...
# 21489           NaN         purchase of a car
# 21495           NaN          wedding ceremony
# 21497           NaN       building a property
# 21502           NaN    building a real estate
# 21510           NaN              car purchase
#
# [2120 rows x 12 columns]

# %%
cse.isna().sum()
# Out:
# children               0
# days_employed       2120
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2120
# purpose                0
# dtype: int64

# %% [markdown]
# Os valores ausentes são simétricos, conforme resultado abaixodo método shape aplicado.

# %%
cse[(cse['days_employed'].isnull()) & (cse['total_income'].isnull())].shape
# Out:
# (2120, 12)

# %% [markdown]
# **Conclusão intermediária**
#
# O número de linhas na tabela é exatamente o mesmo para ambas colunas, 2120, 'days_employed'e 'total_income', indicando que os dados ausentes podem ter a mesma origem.
#
# * O percentual de valores ausentes é de 9,873%, valor já calculado com exclusão de duplicadas.
#
# As próximas tratativas serão a exclusão de **valores duplicados**, tratar e corrigir os **dados ausentes** e eventuais **distorções de valores** das colunas.

# %%
[cse['days_employed'].isnull().sum()/len(cse)*100]
# Out:
# [9.873783242513156]

# %%
cse_null = cse[(cse['days_employed'].isnull()) & (cse['total_income'].isnull())]

cse_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2120 entries, 12 to 21510
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          2120 non-null   int64
#  1   days_employed     0 non-null      float64
#  2   dob_years         2120 non-null   int64
#  3   education         2120 non-null   object
#  4   education_id      2120 non-null   int64
#  5   family_status     2120 non-null   object
#  6   family_status_id  2120 non-null   int64
#  7   gender            2120 non-null   object
#  8   income_type       2120 non-null   object
#  9   debt              2120 non-null   int64
#  10  total_income      0 non-null      float64
#  11  purpose           2120 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 215.3+ KB

# %%
cse_null['income_type'].value_counts(normalize=True)
# Out:
# employee         0.508019
# business         0.237264
# retiree          0.185849
# civil servant    0.068396
# entrepreneur     0.000472
# Name: income_type, dtype: float64

# %% [markdown]
# **Possíveis motivos para valores ausentes nos dados**
#
# 50,8% dos valores ausentes referem-se a pessoas com emprego formal e 23,7% com seu próprio negócio. 18,6% de aposentados. Isso demonstra que trata-se de dado possivelmente não coletado do cliente, ou seja, sem padrão definido.

# %%
cse['income_type'].value_counts(normalize=True)
# Out:
# employee                       0.516557
# business                       0.236598
# retiree                        0.178706
# civil servant                  0.067859
# unemployed                     0.000093
# entrepreneur                   0.000093
# student                        0.000047
# paternity / maternity leave    0.000047
# Name: income_type, dtype: float64

# %% [markdown]
# **Conclusão intermediária**
#
# A distribuição da tabela completa e sem valores nulos seguem a mesma distribuição.

# %%
cse.corr()
# Out:
#                   children  days_employed  dob_years  education_id  \
# children          1.000000      -0.138354  -0.173885     -0.012477
# days_employed    -0.138354       1.000000   0.582643      0.080565
# dob_years        -0.173885       0.582643   1.000000      0.066885
# education_id     -0.012477       0.080565   0.066885      1.000000
# family_status_id -0.091435       0.005726  -0.069684      0.007990
# debt              0.018336      -0.047110  -0.069379      0.052964
# total_income      0.018220      -0.136648  -0.052911     -0.178885
#
#                   family_status_id      debt  total_income
# children                 -0.091435  0.018336      0.018220
# days_employed             0.005726 -0.047110     -0.136648
# dob_years                -0.069684 -0.069379     -0.052911
# education_id              0.007990  0.052964     -0.178885
# family_status_id          1.000000  0.020389     -0.009147
# debt                      0.020389  1.000000     -0.012475
# total_income             -0.009147 -0.012475      1.000000

# %% [markdown]
# **Conclusão intermediária**
#
# De acordo com os dados analisados e tratados, não foi evidenciado padrão para determinar que os valores poderia estar ausentes de forma não acidental.

# %% [markdown]
# **Conclusões**
#
# Nenhum padrão foi encontrado, conforme evidenciado no % de ausentes proporcionais em levantamento realizado com toda a tabela e sem os valores ausentes da coluna tipo de emprego 'income_type'.
#
# Serão tratados os valores ausentes primeiramente verificando se existem correlações entre colunas que subsidiarão tomada de decisão do tipo de tratativa a ser dada para substituição e/ou eventual exclusão de dados.
#
# Antes de tratar os valores ausentes, analisaremos com grandes distorções, valores negativos ou com erro.

# %% [markdown]
# ## Transformação de dados
#
# Será feita a análise por coluna para possível identificação dos dados ausentes apresentados e também valores incorretos e/ou com distorções.
#
# As duplicadas já foram removidas anteriormente.

# %%
cse_edu = cse['education'].unique()
cse_edu
# Out:
# array(["bachelor's degree", 'secondary education', 'Secondary Education',
#        'SECONDARY EDUCATION', "BACHELOR'S DEGREE", 'some college',
#        'primary education', "Bachelor's Degree", 'SOME COLLEGE',
#        'Some College', 'PRIMARY EDUCATION', 'Primary Education',
#        'Graduate Degree', 'GRADUATE DEGREE', 'graduate degree'],
#       dtype=object)

# %%
cse['education'] = cse['education'].str.lower()
cse['education'].unique()
# Out:
# array(["bachelor's degree", 'secondary education', 'some college',
#        'primary education', 'graduate degree'], dtype=object)

# %%
cse['education'].value_counts(normalize=True)
# Out:
# secondary education    0.707373
# bachelor's degree      0.244562
# some college           0.034651
# primary education      0.013134
# graduate degree        0.000279
# Name: education, dtype: float64

# %% [markdown]
# coluna `children`

# %%
cse['children'].value_counts()
# Out:
#  0     14107
#  1      4809
#  2      2052
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %%
cse['children'].value_counts(normalize=True)
# Out:
#  0     0.657026
#  1     0.223977
#  2     0.095571
#  3     0.015370
#  20    0.003540
# -1     0.002189
#  4     0.001910
#  5     0.000419
# Name: children, dtype: float64

# %% [markdown]
# Na coluna 'children' foram identificados dois problemas: valor negativo e um valor irreal de número de filhos. Será feita aplicação da coluna para que demonstre valores absolutos, corrigindo o valor negativo para positivo e alterando *20* para *2* no caso do valor distorcido.

# %%
cse['children'] = cse['children'].replace(20,2)

# %%
cse['children'] = cse['children'].replace(-1,1)

# %%
cse['children'].value_counts(normalize=True)
# Out:
# 0    0.657026
# 1    0.226166
# 2    0.099110
# 3    0.015370
# 4    0.001910
# 5    0.000419
# Name: children, dtype: float64

# %% [markdown]
# coluna `days_employed`

# %%
cse['days_employed'].describe()
# Out:
# count     19351.000000
# mean      63046.497661
# std      140827.311974
# min      -18388.949901
# 25%       -2747.423625
# 50%       -1203.369529
# 75%        -291.095954
# max      401755.400475
# Name: days_employed, dtype: float64

# %%
(cse['days_employed'] < 0).sum()
# Out:
# 15906

# %% [markdown]
# Os dados da coluna 'days_employed' estão em 75% das linhas, ou seja, uma alta incidência. Precisaremos explorar esses dados para posteriormente realizar a correção, pois não podemos descartar essas linhas problemáticas.

# %%
cse[cse['days_employed']<0]
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1   -8437.673028         42    bachelor's degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  secondary education             1
# 3             3   -4124.747207         32  secondary education             1
# 5             0    -926.185831         27    bachelor's degree             0
# ...         ...            ...        ...                  ...           ...
# 21519         1   -2351.431934         37      graduate degree             4
# 21520         1   -4529.316663         43  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 5      civil partnership                 1      M    business     0
# ...                  ...               ...    ...         ...   ...
# 21519           divorced                 3      M    employee     0
# 21520  civil partnership                 1      F    business     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#        total_income                     purpose
# 0         40620.102       purchase of the house
# 1         17932.802                car purchase
# 2         23341.752       purchase of the house
# 3         42820.568     supplementary education
# 5         40922.170       purchase of the house
# ...             ...                         ...
# 21519     18551.846  buy commercial real estate
# 21520     35966.698        housing transactions
# 21522     14347.610                    property
# 21523     39054.888           buying my own car
# 21524     13127.587                to buy a car
#
# [15906 rows x 12 columns]

# %%
cse['days_employed'] = cse['days_employed'].abs()
cse['days_employed'].describe()
# Out:
# count    21454.000000
# mean     13865.457626
# std      24208.813737
# min         24.141633
# 25%       1012.345888
# 50%       2358.542802
# 75%       6073.803283
# max      66914.728907
# Name: days_employed, dtype: float64

# %%
cse_days = cse[cse['days_employed'] < 27365]
mean_days_employed = cse_days['days_employed'].mean()
mean_days_employed
# Out:
# 2353.0159319988766

# %%
median_days_employed = cse_days['days_employed'].median()
median_days_employed
# Out:
# 1630.0193809778218

# %%
pivot_days_genero = cse_days.pivot_table(index = ['dob_years','gender'], values='days_employed', aggfunc ='mean')
pivot_days_genero
# Out:
#                   days_employed
# dob_years gender
# 0         F         2540.659172
#           M         1572.160272
# 19        F          622.060062
#           M          672.404832
# 20        F          619.050333
# ...                         ...
# 72        F         6603.920060
# 73        F         3429.205485
# 74        F         6682.867814
#           M         1729.632531
# 75        F         1678.969771
#
# [114 rows x 1 columns]

# %%
cse_days_2 = cse[cse['days_employed'] >= 27365]
cse_days_2
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 4             0  340266.072047         53  secondary education             1
# 18            0  400281.136913         53  secondary education             1
# 24            1  338551.952911         57  secondary education             1
# 25            0  363548.489348         67  secondary education             1
# 30            1  335581.668515         62  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21505         0  338904.866406         53  secondary education             1
# 21508         0  386497.714078         62  secondary education             1
# 21509         0  362161.054124         59    bachelor's degree             0
# 21518         0  373995.710838         59  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 4      civil partnership                 1      F     retiree     0
# 18       widow / widower                 2      F     retiree     0
# 24             unmarried                 4      F     retiree     0
# 25               married                 0      M     retiree     0
# 30               married                 0      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21505  civil partnership                 1      M     retiree     0
# 21508            married                 0      M     retiree     0
# 21509            married                 0      M     retiree     0
# 21518            married                 0      F     retiree     0
# 21521            married                 0      F     retiree     0
#
#        total_income                                   purpose
# 4         25378.572                         to have a wedding
# 18         9091.804                  buying a second-hand car
# 24        46487.558  transactions with commercial real estate
# 25         8818.041                           buy real estate
# 30        27432.971  transactions with commercial real estate
# ...             ...                                       ...
# 21505     12070.399                         to have a wedding
# 21508     11622.175                                  property
# 21509     11684.650                  real estate transactions
# 21518     24618.344                         purchase of a car
# 21521     24959.969                         purchase of a car
#
# [3445 rows x 12 columns]

# %%
mean_days_employed = cse['days_employed'].mean()
cse.loc[cse['days_employed'] >= 27365, 'days_employed'] = mean_days_employed
cse['days_employed'].describe()
# Out:
# count    21454.000000
# mean      4668.785561
# std       5083.982104
# min         24.141633
# 25%       1012.345888
# 50%       2358.542802
# 75%       6073.803283
# max      23022.470366
# Name: days_employed, dtype: float64

# %%
cse_days.groupby(['dob_years','gender'])['days_employed'].transform('mean')
cse['days_employed'] = cse['days_employed'].fillna(cse.groupby(['dob_years','gender'])['days_employed'].transform('mean'))

# %%
cse_days['days_employed'].value_counts(normalize=True)
# Out:
# 142.276217      0.000063
# 4595.317076     0.000063
# 366.029564      0.000063
# 7375.209318     0.000063
# 799.071855      0.000063
#                   ...
# 2456.531274     0.000063
# 3132.849226     0.000063
# 2139.352596     0.000063
# 10727.562704    0.000063
# 1636.419775     0.000063
# Name: days_employed, Length: 15906, dtype: float64

# %%
cse_days['days_employed'].describe()
# Out:
# count    15906.000000
# mean      2353.015932
# std       2304.243851
# min         24.141633
# 25%        756.371964
# 50%       1630.019381
# 75%       3157.480084
# max      18388.949901
# Name: days_employed, dtype: float64

# %%
cse['days_employed'].head(15)
# Out:
# 0      8437.673028
# 1      4024.803754
# 2      5623.422610
# 3      4124.747207
# 4     66914.728907
# 5       926.185831
# 6      2879.202052
# 7       152.779569
# 8      6929.865299
# 9      2188.756445
# 10     4171.483647
# 11      792.701887
# 12    44256.003683
# 13     1846.641941
# 14     1844.956182
# Name: days_employed, dtype: float64

# %% [markdown]
# coluna 'dob_years'

# %%
cse['dob_years'].value_counts(normalize=True)
# Out:
# 35    0.028690
# 40    0.028271
# 41    0.028224
# 34    0.027991
# 38    0.027805
# 42    0.027758
# 33    0.027060
# 39    0.026641
# 31    0.026035
# 36    0.025802
# 44    0.025383
# 29    0.025337
# 30    0.025057
# 48    0.025010
# 37    0.024964
# 50    0.023893
# 43    0.023846
# 32    0.023706
# 49    0.023660
# 28    0.023427
# 45    0.023148
# 27    0.022961
# 52    0.022542
# 56    0.022542
# 47    0.022216
# 54    0.022169
# 46    0.022030
# 53    0.021378
# 57    0.021238
# 58    0.021238
# 51    0.020865
# 59    0.020632
# 55    0.020632
# 26    0.019002
# 60    0.017419
# 25    0.016627
# 61    0.016487
# 62    0.016254
# 63    0.012529
# 24    0.012296
# 64    0.012203
# 23    0.011783
# 65    0.009035
# 22    0.008523
# 66    0.008477
# 67    0.007778
# 21    0.005170
# 0     0.004704
# 68    0.004611
# 69    0.003959
# 70    0.003027
# 71    0.002701
# 20    0.002375
# 72    0.001537
# 19    0.000652
# 73    0.000373
# 74    0.000279
# 75    0.000047
# Name: dob_years, dtype: float64

# %% [markdown]
# Conforme observado, o % de valores ausentes não segue nenhum padrão ou apresenta evidência do porquê da existencia deles. Serão calculadas as medias e medianas de acordo com o gênero, e aplicaremos o metodo mais adequado para subsituição e correção dos valores ausentes, bem como valores incorretos.

# %%
cse[cse['dob_years']<18]
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 99            0   66914.728907          0  secondary education             1
# 149           0    2664.273168          0  secondary education             1
# 270           3    1872.663186          0  secondary education             1
# 578           0   66914.728907          0  secondary education             1
# 1040          0    1158.029561          0    bachelor's degree             0
# ...         ...            ...        ...                  ...           ...
# 19829         0   18634.176605          0  secondary education             1
# 20462         0   66914.728907          0  secondary education             1
# 20577         0   66914.728907          0  secondary education             1
# 21179         2     108.967042          0    bachelor's degree             0
# 21313         0    1268.487728          0  secondary education             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 99          married                 0      F     retiree     0     11406.644
# 149        divorced                 3      F    employee     0     11228.230
# 270         married                 0      F    employee     0     16346.633
# 578         married                 0      F     retiree     0     15619.310
# 1040       divorced                 3      F    business     0     48639.062
# ...             ...               ...    ...         ...   ...           ...
# 19829       married                 0      F    employee     0           NaN
# 20462       married                 0      F     retiree     0     41471.027
# 20577     unmarried                 4      F     retiree     0     20766.202
# 21179       married                 0      M    business     0     38512.321
# 21313     unmarried                 4      M    employee     0     24387.070
#
#                             purpose
# 99                              car
# 149            housing transactions
# 270              housing renovation
# 578    construction of own property
# 1040                   to own a car
# ...                             ...
# 19829                       housing
# 20462      purchase of my own house
# 20577                      property
# 21179        building a real estate
# 21313          housing transactions
#
# [101 rows x 12 columns]

# %%
cse['dob_years'].median()
# Out:
# 42.0

# %%
cse['dob_years'].mean()
# Out:
# 43.279074099948765

# %%
pivot_days_genero = cse.pivot_table(index = ['days_employed','gender'], values='dob_years', aggfunc ='mean')
pivot_days_genero
# Out:
#                       dob_years
# days_employed gender
# 24.141633     F       31.000000
# 24.240695     M       32.000000
# 30.195337     M       47.000000
# 33.520665     M       43.000000
# 34.701045     F       31.000000
# ...                         ...
# 61849.307381  F       71.000000
# 62724.598665  F       69.000000
# 64047.639066  M       68.000000
# 66914.728907  F       59.173139
#               M       58.912226
#
# [16016 rows x 1 columns]

# %%
pivot_days_genero = cse.pivot_table(index = ['days_employed','gender'], values='dob_years', aggfunc ='mean')
pivot_days_genero
# Out:
#                       dob_years
# days_employed gender
# 24.141633     F       31.000000
# 24.240695     M       32.000000
# 30.195337     M       47.000000
# 33.520665     M       43.000000
# 34.701045     F       31.000000
# ...                         ...
# 61849.307381  F       71.000000
# 62724.598665  F       69.000000
# 64047.639066  M       68.000000
# 66914.728907  F       59.173139
#               M       58.912226
#
# [16016 rows x 1 columns]

# %%
cse['dob_years'].replace(0, cse['dob_years'].median() , inplace=True)
cse['dob_years'].describe()
# Out:
# count    21454.000000
# mean        43.468957
# std         12.213881
# min         19.000000
# 25%         33.000000
# 50%         42.000000
# 75%         53.000000
# max         75.000000
# Name: dob_years, dtype: float64

# %%
cse['dob_years'].value_counts(normalize=True).sort_index()
# Out:
# 19.0    0.000652
# 20.0    0.002375
# 21.0    0.005170
# 22.0    0.008523
# 23.0    0.011783
# 24.0    0.012296
# 25.0    0.016627
# 26.0    0.019002
# 27.0    0.022961
# 28.0    0.023427
# 29.0    0.025337
# 30.0    0.025057
# 31.0    0.026035
# 32.0    0.023706
# 33.0    0.027060
# 34.0    0.027991
# 35.0    0.028690
# 36.0    0.025802
# 37.0    0.024964
# 38.0    0.027805
# 39.0    0.026641
# 40.0    0.028271
# 41.0    0.028224
# 42.0    0.032462
# 43.0    0.023846
# 44.0    0.025383
# 45.0    0.023148
# 46.0    0.022030
# 47.0    0.022216
# 48.0    0.025010
# 49.0    0.023660
# 50.0    0.023893
# 51.0    0.020865
# 52.0    0.022542
# 53.0    0.021378
# 54.0    0.022169
# 55.0    0.020632
# 56.0    0.022542
# 57.0    0.021238
# 58.0    0.021238
# 59.0    0.020632
# 60.0    0.017419
# 61.0    0.016487
# 62.0    0.016254
# 63.0    0.012529
# 64.0    0.012203
# 65.0    0.009035
# 66.0    0.008477
# 67.0    0.007778
# 68.0    0.004611
# 69.0    0.003959
# 70.0    0.003027
# 71.0    0.002701
# 72.0    0.001537
# 73.0    0.000373
# 74.0    0.000279
# 75.0    0.000047
# Name: dob_years, dtype: float64

# %% [markdown]
# coluna `family_status`

# %%
cse['family_status'].value_counts(dropna=False)
# Out:
# married              12344
# civil partnership     4163
# unmarried             2810
# divorced              1195
# widow / widower        959
# Name: family_status, dtype: int64

# %%
cse['family_status'].describe()
# Out:
# count       21471
# unique          5
# top       married
# freq        12344
# Name: family_status, dtype: object

# %%
cse.groupby('dob_years')['family_status'].value_counts()
# Out:
# dob_years  family_status
# 19.0       unmarried             7
#            civil partnership     4
#            married               3
# 20.0       unmarried            26
#            civil partnership    12
#                                 ..
# 73.0       civil partnership     1
# 74.0       married               4
#            civil partnership     1
#            widow / widower       1
# 75.0       widow / widower       1
# Name: family_status, Length: 267, dtype: int64

# %% [markdown]
# coluna `gender`

# %%
cse['gender'].value_counts(dropna=False)
# Out:
# F      14189
# M       7281
# XNA        1
# Name: gender, dtype: int64

# %%
index = cse.loc[cse['gender'] == 'XNA']
print(index)
# Out:
#        children  days_employed  dob_years     education  education_id  \
# 10701         0    2358.600502       24.0  some college             2
#
#            family_status  family_status_id gender income_type  debt  \
# 10701  civil partnership                 1    XNA    business     0
#
#        total_income          purpose
# 10701     32624.825  buy real estate

# %%
cse_null['gender'].value_counts(normalize=True)
# Out:
# F    0.67783
# M    0.32217
# Name: gender, dtype: float64

# %%
cse['gender'].describe()
# Out:
# count     21471
# unique        3
# top           F
# freq      14189
# Name: gender, dtype: object

# %% [markdown]
# coluna `income_type`

# %%
cse['income_type'].value_counts(dropna=False)
# Out:
# employee                       11091
# business                        5080
# retiree                         3837
# civil servant                   1457
# unemployed                         2
# entrepreneur                       2
# student                            1
# paternity / maternity leave        1
# Name: income_type, dtype: int64

# %%
cse['income_type'].describe()
# Out:
# count        21471
# unique           8
# top       employee
# freq         11091
# Name: income_type, dtype: object

# %%
cse.groupby('dob_years')['income_type'].describe()
# Out:
#           count unique            top freq
# dob_years
# 19.0         14      3       business    7
# 20.0         51      3       employee   33
# 21.0        111      3       employee   69
# 22.0        183      5       employee  111
# 23.0        253      3       employee  175
# 24.0        264      4       employee  162
# 25.0        357      3       employee  222
# 26.0        408      4       employee  249
# 27.0        493      5       employee  309
# 28.0        503      4       employee  314
# 29.0        544      3       employee  347
# 30.0        538      3       employee  331
# 31.0        559      5       employee  329
# 32.0        509      4       employee  339
# 33.0        581      4       employee  383
# 34.0        601      4       employee  377
# 35.0        616      4       employee  378
# 36.0        554      4       employee  334
# 37.0        536      4       employee  338
# 38.0        597      4       employee  364
# 39.0        572      5       employee  359
# 40.0        607      4       employee  377
# 41.0        606      4       employee  376
# 42.0        697      4       employee  416
# 43.0        512      4       employee  324
# 44.0        545      4       employee  338
# 45.0        497      5       employee  319
# 46.0        473      4       employee  291
# 47.0        477      4       employee  289
# 48.0        537      4       employee  316
# 49.0        508      4       employee  321
# 50.0        513      4       employee  275
# 51.0        448      4       employee  219
# 52.0        484      4       employee  231
# 53.0        459      4       employee  202
# 54.0        476      4       employee  203
# 55.0        443      4       employee  183
# 56.0        484      4        retiree  208
# 57.0        456      4        retiree  246
# 58.0        456      5        retiree  237
# 59.0        443      4        retiree  275
# 60.0        374      4        retiree  268
# 61.0        354      4        retiree  241
# 62.0        349      4        retiree  260
# 63.0        269      4        retiree  210
# 64.0        262      4        retiree  205
# 65.0        194      4        retiree  153
# 66.0        182      4        retiree  156
# 67.0        167      3        retiree  147
# 68.0         99      3        retiree   87
# 69.0         85      4        retiree   77
# 70.0         65      4        retiree   56
# 71.0         58      4        retiree   53
# 72.0         33      2        retiree   29
# 73.0          8      2        retiree    7
# 74.0          6      3        retiree    4
# 75.0          1      1  civil servant    1

# %% [markdown]
# Confirmando abaixo a remoção feita anteriormente de valores duplicados

# %%
cse.duplicated().sum()
cse = cse.drop_duplicates()

# %%
cse.duplicated().sum()
# Out:
# 0

# %%
cse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21454 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21454 non-null  int64
#  1   days_employed     21454 non-null  float64
#  2   dob_years         21454 non-null  float64
#  3   education         21454 non-null  object
#  4   education_id      21454 non-null  int64
#  5   family_status     21454 non-null  object
#  6   family_status_id  21454 non-null  int64
#  7   gender            21454 non-null  object
#  8   income_type       21454 non-null  object
#  9   debt              21454 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21454 non-null  object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# As correções reduziram significamente os valores ausentes. Agora faremos os demais ajustes dos valores ainda não realizados.

# %% [markdown]
# # Trabalhando com valores ausentes

# %% [markdown]
# Serão utilizados adicionalmente bibliotecas com dados sobre educação/escolaridade.

# %%
cse
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1    8437.673028       42.0    bachelor's degree             0
# 1             1    4024.803754       36.0  secondary education             1
# 2             0    5623.422610       33.0  secondary education             1
# 3             3    4124.747207       32.0  secondary education             1
# 4             0   66914.728907       53.0  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1    4529.316663       43.0  secondary education             1
# 21521         0   66914.728907       67.0  secondary education             1
# 21522         1    2113.346888       38.0  secondary education             1
# 21523         3    3112.481705       38.0  secondary education             1
# 21524         2    1984.507589       40.0  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F    business     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#        total_income                  purpose
# 0         40620.102    purchase of the house
# 1         17932.802             car purchase
# 2         23341.752    purchase of the house
# 3         42820.568  supplementary education
# 4         25378.572        to have a wedding
# ...             ...                      ...
# 21520     35966.698     housing transactions
# 21521     24959.969        purchase of a car
# 21522     14347.610                 property
# 21523     39054.888        buying my own car
# 21524     13127.587             to buy a car
#
# [21454 rows x 12 columns]

# %%
education_dict=cse[['education_id', 'education']]
education_dict=education_dict.drop_duplicates().reset_index(drop=True)
education_dict
# Out:
#    education_id            education
# 0             0    bachelor's degree
# 1             1  secondary education
# 2             2         some college
# 3             3    primary education
# 4             4      graduate degree

# %%
education_dict=cse['education'].str.lower()

# %% [markdown]
# ### Restaurar valores ausentes em `total_income`

# %% [markdown]
# A coluna 'total_income' apresenta ainda valores ausentes. Serão feitos calculos de media e mediana de acordo com a idade e gênero para tomada de decisão do método mais adequado para substituir os valores ausentes ainda não corrigidos.

# %%
def cat_age(age):
    if age <= 18:
        return 'young'
    if age <=60:
        return 'adult'
    return 'eldery'

# %%
# Teste se a função funciona
print(cat_age(2))
print(cat_age(40))
print(cat_age(80))
# Out:
# young
# adult
# eldery

# %%
cse['age_category'] = cse['dob_years'].apply(cat_age)

# %%
cse.head(15)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1    8437.673028       42.0    bachelor's degree             0
# 1          1    4024.803754       36.0  secondary education             1
# 2          0    5623.422610       33.0  secondary education             1
# 3          3    4124.747207       32.0  secondary education             1
# 4          0   66914.728907       53.0  secondary education             1
# 5          0     926.185831       27.0    bachelor's degree             0
# 6          0    2879.202052       43.0    bachelor's degree             0
# 7          0     152.779569       50.0  secondary education             1
# 8          2    6929.865299       35.0    bachelor's degree             0
# 9          0    2188.756445       41.0  secondary education             1
# 10         2    4171.483647       36.0    bachelor's degree             0
# 11         0     792.701887       40.0  secondary education             1
# 12         0   44256.003683       65.0  secondary education             1
# 13         0    1846.641941       54.0         some college             2
# 14         0    1844.956182       56.0    bachelor's degree             0
#
#         family_status  family_status_id gender income_type  debt  \
# 0             married                 0      F    employee     0
# 1             married                 0      F    employee     0
# 2             married                 0      M    employee     0
# 3             married                 0      M    employee     0
# 4   civil partnership                 1      F     retiree     0
# 5   civil partnership                 1      M    business     0
# 6             married                 0      F    business     0
# 7             married                 0      M    employee     0
# 8   civil partnership                 1      F    employee     0
# 9             married                 0      M    employee     0
# 10            married                 0      M    business     0
# 11            married                 0      F    employee     0
# 12  civil partnership                 1      M     retiree     0
# 13            married                 0      F    employee     0
# 14  civil partnership                 1      F    business     1
#
#     total_income                              purpose age_category
# 0      40620.102                purchase of the house        adult
# 1      17932.802                         car purchase        adult
# 2      23341.752                purchase of the house        adult
# 3      42820.568              supplementary education        adult
# 4      25378.572                    to have a wedding        adult
# 5      40922.170                purchase of the house        adult
# 6      38484.156                 housing transactions        adult
# 7      21731.829                            education        adult
# 8      15337.093                     having a wedding        adult
# 9      23108.150  purchase of the house for my family        adult
# 10     18230.959                      buy real estate        adult
# 11     12331.077           buy commercial real estate        adult
# 12           NaN                    to have a wedding       eldery
# 13     20873.317                         car purchase        adult
# 14     26420.466          buy residential real estate        adult

# %%
cse_sem_nulos = cse[cse['days_employed'].notna()]
cse_sem_nulos
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1    8437.673028       42.0    bachelor's degree             0
# 1             1    4024.803754       36.0  secondary education             1
# 2             0    5623.422610       33.0  secondary education             1
# 3             3    4124.747207       32.0  secondary education             1
# 4             0   66914.728907       53.0  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1    4529.316663       43.0  secondary education             1
# 21521         0   66914.728907       67.0  secondary education             1
# 21522         1    2113.346888       38.0  secondary education             1
# 21523         3    3112.481705       38.0  secondary education             1
# 21524         2    1984.507589       40.0  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F    business     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#        total_income                  purpose age_category
# 0         40620.102    purchase of the house        adult
# 1         17932.802             car purchase        adult
# 2         23341.752    purchase of the house        adult
# 3         42820.568  supplementary education        adult
# 4         25378.572        to have a wedding        adult
# ...             ...                      ...          ...
# 21520     35966.698     housing transactions        adult
# 21521     24959.969        purchase of a car       eldery
# 21522     14347.610                 property        adult
# 21523     39054.888        buying my own car        adult
# 21524     13127.587             to buy a car        adult
#
# [21454 rows x 13 columns]

# %%
cse_sem_nulos['total_income'].mean()
# Out:
# 26787.568354658677

# %%
cse_sem_nulos['total_income'].median()
# Out:
# 23202.87

# %%
cse_sem_nulos.pivot_table(index='gender', values='total_income',aggfunc = 'mean')
# Out:
#         total_income
# gender
# F       24655.604757
# M       30907.144369
# XNA     32624.825000

# %%
cse_sem_nulos.pivot_table(index=['education','gender'], values='total_income',aggfunc = 'median')
# Out:
#                             total_income
# education           gender
# bachelor's degree   F         26063.4715
#                     M         32675.8355
# graduate degree     F         29345.3940
#                     M         25161.5835
# primary education   F         17223.9615
#                     M         21204.0860
# secondary education F         20101.2700
#                     M         25435.5815
# some college        F         22836.0820
#                     M         29973.6640
#                     XNA       32624.8250

# %%
pivot_education_genero = cse_sem_nulos.pivot_table(index = ['education','gender'], values='total_income', aggfunc ='mean')
pivot_education_genero
# Out:
#                             total_income
# education           gender
# bachelor's degree   F       30306.441576
#                     M       38981.070503
# graduate degree     F       29345.394000
#                     M       27267.340000
# primary education   F       19118.479588
#                     M       23798.931664
# secondary education F       22671.099805
#                     M       28296.294264
# some college        F       26470.312199
#                     M       33209.842210
#                     XNA     32624.825000

# %%
pivot_education_genero = cse_sem_nulos.pivot_table(index = ['education','gender'], values='total_income', aggfunc ='median')
pivot_education_genero
# Out:
#                             total_income
# education           gender
# bachelor's degree   F         26063.4715
#                     M         32675.8355
# graduate degree     F         29345.3940
#                     M         25161.5835
# primary education   F         17223.9615
#                     M         21204.0860
# secondary education F         20101.2700
#                     M         25435.5815
# some college        F         22836.0820
#                     M         29973.6640
#                     XNA       32624.8250

# %%
pivot_education_genero['total_income']["bachelor's degree"]['M']
# Out:
# 32675.8355

# %% [markdown]
# Serão utilizadas as médias calculadas de acordo com a coluna gênero e education.

# %%
def fill_total_income(row):
    
    total_income = row['total_income']
    educacao = row['education']
    genero = row['gender']
    
    if pd.isna(total_income):
        return pivot_education_genero['total_income'][educacao][genero]
    return total_income

# %%
cse['total_income'].describe()
# Out:
# count     19351.000000
# mean      26787.568355
# std       16475.450632
# min        3306.762000
# 25%       16488.504500
# 50%       23202.870000
# 75%       32549.611000
# max      362496.645000
# Name: total_income, dtype: float64

# %%
cse['total_income'] = cse.apply(fill_total_income, axis=1)

# %%
cse['total_income'].isna().sum()
# Out:
# 0

# %%
cse.groupby(['education','gender'])['total_income'].transform('median')
cse['total_income'] = cse['total_income'].fillna(cse.groupby(['education','gender'])['total_income'].transform('median'))
print(cse.head(10))
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1    8437.673028       42.0    bachelor's degree             0
# 1         1    4024.803754       36.0  secondary education             1
# 2         0    5623.422610       33.0  secondary education             1
# 3         3    4124.747207       32.0  secondary education             1
# 4         0   66914.728907       53.0  secondary education             1
# 5         0     926.185831       27.0    bachelor's degree             0
# 6         0    2879.202052       43.0    bachelor's degree             0
# 7         0     152.779569       50.0  secondary education             1
# 8         2    6929.865299       35.0    bachelor's degree             0
# 9         0    2188.756445       41.0  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
# 5  civil partnership                 1      M    business     0     40922.170
# 6            married                 0      F    business     0     38484.156
# 7            married                 0      M    employee     0     21731.829
# 8  civil partnership                 1      F    employee     0     15337.093
# 9            married                 0      M    employee     0     23108.150
#
#                                purpose age_category
# 0                purchase of the house        adult
# 1                         car purchase        adult
# 2                purchase of the house        adult
# 3              supplementary education        adult
# 4                    to have a wedding        adult
# 5                purchase of the house        adult
# 6                 housing transactions        adult
# 7                            education        adult
# 8                     having a wedding        adult
# 9  purchase of the house for my family        adult

# %%
cse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21454 entries, 0 to 21524
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21454 non-null  int64
#  1   days_employed     21454 non-null  float64
#  2   dob_years         21454 non-null  float64
#  3   education         21454 non-null  object
#  4   education_id      21454 non-null  int64
#  5   family_status     21454 non-null  object
#  6   family_status_id  21454 non-null  int64
#  7   gender            21454 non-null  object
#  8   income_type       21454 non-null  object
#  9   debt              21454 non-null  int64
#  10  total_income      21454 non-null  float64
#  11  purpose           21454 non-null  object
#  12  age_category      21454 non-null  object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 2.3+ MB

# %% [markdown]
# ###  Restaurar valores em `days_employed`

# %% [markdown]
# [Pense nos parâmetros que podem ajudá-lo a restaurar os valores ausentes nesta coluna. Eventualmente, você desejará descobrir se deve usar valores médios ou medianos para substituir valores ausentes. Você provavelmente fará uma pesquisa semelhante à que fez ao restaurar dados em uma coluna anterior.]

# %%
cse['days_employed'].median()
# Out:
# 2358.5428021913895

# %%
cse['days_employed'].mean()
# Out:
# 13865.457625616455

# %% [markdown]
# Os valores ausentes da coluna days_employed já foram restaurados acima, quando estavamos tratando por coluna. E também explicado que foram utilizados as médias para realizar a substituição.

# %%
cse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21454 entries, 0 to 21524
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21454 non-null  int64
#  1   days_employed     21454 non-null  float64
#  2   dob_years         21454 non-null  float64
#  3   education         21454 non-null  object
#  4   education_id      21454 non-null  int64
#  5   family_status     21454 non-null  object
#  6   family_status_id  21454 non-null  int64
#  7   gender            21454 non-null  object
#  8   income_type       21454 non-null  object
#  9   debt              21454 non-null  int64
#  10  total_income      21454 non-null  float64
#  11  purpose           21454 non-null  object
#  12  age_category      21454 non-null  object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Categorização de dados
#
# [Para responder às perguntas e testar as hipóteses, você vai querer trabalhar com dados categorizados. Veja as perguntas que lhe foram colocadas e que você deve responder. Pense em quais dados precisarão ser categorizados para responder a essas perguntas. Abaixo, você encontrará um modelo por meio do qual poderá trabalhar à sua maneira ao categorizar os dados. O primeiro processamento passo a passo abrange os dados de texto; o segundo aborda os dados numéricos que precisam ser categorizados. Você pode usar ambas ou nenhuma das instruções sugeridas - você decide.]
#
# [Independentemente de como você decidir abordar a categorização, certifique-se de fornecer uma explicação clara do por quê você tomou sua decisão. Lembre-se: este é o seu trabalho e você toma todas as decisões nele.]

# %%
print(cse.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21454 entries, 0 to 21524
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21454 non-null  int64
#  1   days_employed     21454 non-null  float64
#  2   dob_years         21454 non-null  float64
#  3   education         21454 non-null  object
#  4   education_id      21454 non-null  int64
#  5   family_status     21454 non-null  object
#  6   family_status_id  21454 non-null  int64
#  7   gender            21454 non-null  object
#  8   income_type       21454 non-null  object
#  9   debt              21454 non-null  int64
#  10  total_income      21454 non-null  float64
#  11  purpose           21454 non-null  object
#  12  age_category      21454 non-null  object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 2.3+ MB
# None

# %%
cse['purpose'].unique()
# Out:
# array(['purchase of the house', 'car purchase', 'supplementary education',
#        'to have a wedding', 'housing transactions', 'education',
#        'having a wedding', 'purchase of the house for my family',
#        'buy real estate', 'buy commercial real estate',
#        'buy residential real estate', 'construction of own property',
#        'property', 'building a property', 'buying a second-hand car',
#        'buying my own car', 'transactions with commercial real estate',
#        'building a real estate', 'housing',
#        'transactions with my real estate', 'cars', 'to become educated',
#        'second-hand car purchase', 'getting an education', 'car',
#        'wedding ceremony', 'to get a supplementary education',
#        'purchase of my own house', 'real estate transactions',
#        'getting higher education', 'to own a car', 'purchase of a car',
#        'profile education', 'university education',
#        'buying property for renting out', 'to buy a car',
#        'housing renovation', 'going to university'], dtype=object)

# %%
cse['education'].unique()
# Out:
# array(["bachelor's degree", 'secondary education', 'some college',
#        'primary education', 'graduate degree'], dtype=object)

# %%
cse['debt'].unique()
# Out:
# array([0, 1])

# %%
cse['income_type'].unique()
# Out:
# array(['employee', 'retiree', 'business', 'civil servant', 'unemployed',
#        'entrepreneur', 'student', 'paternity / maternity leave'],
#       dtype=object)

# %%
cse['gender'].unique()
# Out:
# array(['F', 'M', 'XNA'], dtype=object)

# %%
cse['family_status'].unique()
# Out:
# array(['married', 'civil partnership', 'widow / widower', 'divorced',
#        'unmarried'], dtype=object)

# %%
cse['total_income'].unique()
# Out:
# array([40620.102, 17932.802, 23341.752, ..., 14347.61 , 39054.888,
#        13127.587])

# %%
def debt_group(debt):
    
    if debt == 0:
        return 'Adimplente'
    if debt == 1:
        return 'Histórico Inadimplencia'

print(debt_group(0))
print(debt_group(1))
# Out:
# Adimplente
# Histórico Inadimplencia

# %%
for index, row in cse.iterrows():
    if isinstance(row['purpose'], str) and 'education' in row['purpose'] or 'educated' in row['purpose'] or 'university' in row['purpose']:
        cse.at[index, 'purpose_categoria'] = 'education'
    elif isinstance(row['purpose'], str) and ('car' in row['purpose'] or 'cars' in row['purpose']):
        cse.at[index, 'purpose_categoria'] = 'cars'
    elif isinstance(row['purpose'], str) and 'wedding' in row['purpose']:
        cse.at[index, 'purpose_categoria'] = 'wedding'
    elif isinstance(row['purpose'], str) and ('house' in row['purpose'] or 'housing' in row['purpose'] or 'property' in row['purpose'] or 'real estate' in row['purpose']):
        cse.at[index, 'purpose_categoria'] = 'house'
        
print(cse['purpose_categoria'].head(15))
print(cse.head())
print(cse.info())
# Out:
# 0         house
# 1          cars
# 2         house
# 3     education
# 4       wedding
# 5         house
# 6         house
# 7     education
# 8       wedding
# 9         house
# 10        house
# 11        house
# 12      wedding
# 13         cars
# 14        house
# Name: purpose_categoria, dtype: object
#    children  days_employed  dob_years            education  education_id  \
# 0         1    8437.673028       42.0    bachelor's degree             0
# 1         1    4024.803754       36.0  secondary education             1
# 2         0    5623.422610       33.0  secondary education             1
# 3         3    4124.747207       32.0  secondary education             1
# 4         0   66914.728907       53.0  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
#
#                    purpose age_category purpose_categoria
# 0    purchase of the house        adult             house
# 1             car purchase        adult              cars
# 2    purchase of the house        adult             house
# 3  supplementary education        adult         education
# 4        to have a wedding        adult           wedding
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21454 entries, 0 to 21524
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   children           21454 non-null  int64
#  1   days_employed      21454 non-null  float64
#  2   dob_years          21454 non-null  float64
#  3   education          21454 non-null  object
#  4   education_id       21454 non-null  int64
#  5   family_status      21454 non-null  object
#  6   family_status_id   21454 non-null  int64
#  7   gender             21454 non-null  object
#  8   income_type        21454 non-null  object
#  9   debt               21454 non-null  int64
#  10  total_income       21454 non-null  float64
#  11  purpose            21454 non-null  object
#  12  age_category       21454 non-null  object
#  13  purpose_categoria  21454 non-null  object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 3.0+ MB
# None

# %%
cse.groupby(['children', 'dob_years', 'total_income'])['debt'].median()
# Out:
# children  dob_years  total_income
# 0         19.0       9459.8510       0.0
#                      10963.8570      0.0
#                      12125.9860      0.0
#                      12929.9440      0.0
#                      14575.7170      0.0
#                                     ...
# 5         36.0       26953.7480      0.0
#           37.0       41071.7360      0.0
#           38.0       34007.2590      0.0
#           42.0       25435.5815      0.0
#           59.0       43050.9360      0.0
# Name: debt, Length: 19866, dtype: float64

# %%
cse.groupby(['children', 'dob_years', 'total_income'])['debt'].sum()
# Out:
# children  dob_years  total_income
# 0         19.0       9459.8510       0
#                      10963.8570      0
#                      12125.9860      0
#                      12929.9440      0
#                      14575.7170      0
#                                     ..
# 5         36.0       26953.7480      0
#           37.0       41071.7360      0
#           38.0       34007.2590      0
#           42.0       25435.5815      0
#           59.0       43050.9360      0
# Name: debt, Length: 19866, dtype: int64

# %%
cse.groupby(['children', 'dob_years', 'debt'])['total_income'].mean()
# Out:
# children  dob_years  debt
# 0         19.0       0       17801.687115
#                      1       14934.901000
#           20.0       0       20129.247014
#                      1       17737.316000
#           21.0       0       23996.384076
#                                  ...
# 5         36.0       0       17378.705500
#           37.0       0       41071.736000
#           38.0       0       34007.259000
#           42.0       0       25435.581500
#           59.0       0       43050.936000
# Name: total_income, Length: 364, dtype: float64

# %%
cse.groupby(['children', 'dob_years', 'debt'])['total_income'].median()
# Out:
# children  dob_years  debt
# 0         19.0       0       16588.2370
#                      1       14934.9010
#           20.0       0       17257.2770
#                      1       19975.1040
#           21.0       0       21361.7300
#                                 ...
# 5         36.0       0       17378.7055
#           37.0       0       41071.7360
#           38.0       0       34007.2590
#           42.0       0       25435.5815
#           59.0       0       43050.9360
# Name: total_income, Length: 364, dtype: float64

# %%
cse.groupby(['children', 'dob_years', 'debt'])['total_income'].head()
# Out:
# 0        40620.1020
# 1        17932.8020
# 2        23341.7520
# 3        42820.5680
# 4        25378.5720
#             ...
# 21333    21125.1220
# 21390    25435.5815
# 21412    42408.8810
# 21456    18446.6750
# 21523    39054.8880
# Name: total_income, Length: 1475, dtype: float64

# %%
print('DOB YEARS')

dob_years = cse['dob_years']

def categorizar_dob_years(dob_years):
    if dob_years <= 18:
        return 'young'
    elif dob_years <=60:
        return 'adult'
    else:
        return 'eldery'
  
cse['cat_dob_years'] = dob_years.apply(categorizar_dob_years)
print(cse[['dob_years', 'cat_dob_years']].head(15))    


print('COLUNA CHILDREN')

children = cse['children']

def categorizar_children(children):
    if children <= 1:
        return 'até 1 filho'
    elif children <= 3:
        return 'até 3 filhos'
    else:
        return 'até 5 filhos'
    
cse['cat_children'] = children.apply(categorizar_children)
print(cse[['children', 'cat_children']].head(15)) 


print('TOTAL INCOME')

total_income = cse['total_income']

def categorizar_total_income(income):
    if income <= 30000:
        return 'até 30 mil'
    elif income <= 50000:
        return '30 a 50 mil'
    else:
        return 'acima de 50 mil'
    
cse['cat_total_income'] = total_income.apply(categorizar_total_income)
print(cse[['total_income', 'cat_total_income']].head(15))
# Out:
# DOB YEARS
#     dob_years cat_dob_years
# 0        42.0         adult
# 1        36.0         adult
# 2        33.0         adult
# 3        32.0         adult
# 4        53.0         adult
# 5        27.0         adult
# 6        43.0         adult
# 7        50.0         adult
# 8        35.0         adult
# 9        41.0         adult
# 10       36.0         adult
# 11       40.0         adult
# 12       65.0        eldery
# 13       54.0         adult
# 14       56.0         adult
# COLUNA CHILDREN
#     children  cat_children
# 0          1   até 1 filho
# 1          1   até 1 filho
# 2          0   até 1 filho
# 3          3  até 3 filhos
# 4          0   até 1 filho
# 5          0   até 1 filho
# 6          0   até 1 filho
# 7          0   até 1 filho
# 8          2  até 3 filhos
# 9          0   até 1 filho
# 10         2  até 3 filhos
# 11         0   até 1 filho
# 12         0   até 1 filho
# 13         0   até 1 filho
# 14         0   até 1 filho
# TOTAL INCOME
#     total_income cat_total_income
# 0     40620.1020      30 a 50 mil
# 1     17932.8020       até 30 mil
# 2     23341.7520       até 30 mil
# 3     42820.5680      30 a 50 mil
# 4     25378.5720       até 30 mil
# 5     40922.1700      30 a 50 mil
# 6     38484.1560      30 a 50 mil
# 7     21731.8290       até 30 mil
# 8     15337.0930       até 30 mil
# 9     23108.1500       até 30 mil
# 10    18230.9590       até 30 mil
# 11    12331.0770       até 30 mil
# 12    25435.5815       até 30 mil
# 13    20873.3170       até 30 mil
# 14    26420.4660       até 30 mil

# %%
cse['cat_dob_years'] = cse['dob_years']
print(cse.head(10))
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1    8437.673028       42.0    bachelor's degree             0
# 1         1    4024.803754       36.0  secondary education             1
# 2         0    5623.422610       33.0  secondary education             1
# 3         3    4124.747207       32.0  secondary education             1
# 4         0   66914.728907       53.0  secondary education             1
# 5         0     926.185831       27.0    bachelor's degree             0
# 6         0    2879.202052       43.0    bachelor's degree             0
# 7         0     152.779569       50.0  secondary education             1
# 8         2    6929.865299       35.0    bachelor's degree             0
# 9         0    2188.756445       41.0  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
# 5  civil partnership                 1      M    business     0     40922.170
# 6            married                 0      F    business     0     38484.156
# 7            married                 0      M    employee     0     21731.829
# 8  civil partnership                 1      F    employee     0     15337.093
# 9            married                 0      M    employee     0     23108.150
#
#                                purpose age_category purpose_categoria  \
# 0                purchase of the house        adult             house
# 1                         car purchase        adult              cars
# 2                purchase of the house        adult             house
# 3              supplementary education        adult         education
# 4                    to have a wedding        adult           wedding
# 5                purchase of the house        adult             house
# 6                 housing transactions        adult             house
# 7                            education        adult         education
# 8                     having a wedding        adult           wedding
# 9  purchase of the house for my family        adult             house
#
#    cat_dob_years  cat_children cat_total_income
# 0           42.0   até 1 filho      30 a 50 mil
# 1           36.0   até 1 filho       até 30 mil
# 2           33.0   até 1 filho       até 30 mil
# 3           32.0  até 3 filhos      30 a 50 mil
# 4           53.0   até 1 filho       até 30 mil
# 5           27.0   até 1 filho      30 a 50 mil
# 6           43.0   até 1 filho      30 a 50 mil
# 7           50.0   até 1 filho       até 30 mil
# 8           35.0  até 3 filhos       até 30 mil
# 9           41.0   até 1 filho       até 30 mil

# %%
print(cse[['dob_years', 'cat_dob_years']].value_counts())  
print(cse[['children', 'cat_children']].value_counts())  
print(cse[['total_income', 'cat_total_income']].value_counts())
# Out:
# dob_years  cat_dob_years
# 42.0       42.0             697
# 35.0       35.0             616
# 40.0       40.0             607
# 41.0       41.0             605
# 34.0       34.0             601
# 38.0       38.0             597
# 33.0       33.0             581
# 39.0       39.0             572
# 31.0       31.0             559
# 36.0       36.0             554
# 44.0       44.0             545
# 29.0       29.0             544
# 30.0       30.0             537
# 48.0       48.0             536
# 37.0       37.0             536
# 50.0       50.0             513
# 43.0       43.0             512
# 32.0       32.0             509
# 49.0       49.0             508
# 28.0       28.0             503
# 45.0       45.0             496
# 27.0       27.0             493
# 52.0       52.0             484
# 56.0       56.0             483
# 47.0       47.0             477
# 54.0       54.0             476
# 46.0       46.0             472
# 53.0       53.0             459
# 57.0       57.0             456
# 58.0       58.0             454
# 51.0       51.0             446
# 59.0       59.0             443
# 55.0       55.0             443
# 26.0       26.0             408
# 60.0       60.0             374
# 25.0       25.0             357
# 61.0       61.0             354
# 62.0       62.0             348
# 63.0       63.0             269
# 24.0       24.0             264
# 64.0       64.0             260
# 23.0       23.0             252
# 65.0       65.0             193
# 22.0       22.0             183
# 66.0       66.0             182
# 67.0       67.0             167
# 21.0       21.0             111
# 68.0       68.0              99
# 69.0       69.0              85
# 70.0       70.0              65
# 71.0       71.0              56
# 20.0       20.0              51
# 72.0       72.0              33
# 19.0       19.0              14
# 73.0       73.0               8
# 74.0       74.0               6
# 75.0       75.0               1
# dtype: int64
# children  cat_children
# 0         até 1 filho     14091
# 1         até 1 filho      4855
# 2         até 3 filhos     2128
# 3         até 3 filhos      330
# 4         até 5 filhos       41
# 5         até 5 filhos        9
# dtype: int64
# total_income  cat_total_income
# 20101.2700    até 30 mil          1000
# 25435.5815    até 30 mil           480
# 26063.4715    até 30 mil           365
# 32675.8355    30 a 50 mil          169
# 22836.0820    até 30 mil            44
#                                   ...
# 18582.2900    até 30 mil             1
# 18581.8020    até 30 mil             1
# 18576.3480    até 30 mil             1
# 18574.9670    até 30 mil             1
# 362496.6450   acima de 50 mil        1
# Length: 19352, dtype: int64

# %% [markdown]
# ## Verificar as Hipóteses

# %% [markdown]
# **Existe uma correlação entre o nível de renda e do pagamento em dia?**

# %%
pivot_table_children = cse.pivot_table(index = 'children', columns='debt', values='dob_years', aggfunc='count')
pivot_table_children

pivot_table_children['percent_1'] = pivot_table_children[1] / (pivot_table_children[1]+ pivot_table_children[0]) * 100
pivot_table_children.sort_values(by='percent_1', ascending=True)
# Out:
# debt            0       1  percent_1
# children
# 0         13028.0  1063.0   7.543822
# 3           303.0    27.0   8.181818
# 1          4410.0   445.0   9.165808
# 2          1926.0   202.0   9.492481
# 4            37.0     4.0   9.756098
# 5             9.0     NaN        NaN

# %% [markdown]
# **Conclusão**
#
# Cliente com e sem filhos, em todas as faixas de renda, apresentaram taxa de inadimplência entre 7,54 (sem filhos) a 9,75% (4 filhos).

# %% [markdown]
# **Existe uma correlação entre o status familiar e o pagamento em dia?**

# %%
pivot_table_family_status = cse.pivot_table(index = 'family_status', columns='debt', values='dob_years', aggfunc='count')
pivot_table_family_status

pivot_table_family_status['percent_2'] = pivot_table_family_status[1] / (pivot_table_family_status[1]+ pivot_table_family_status[0]) * 100
pivot_table_family_status.sort_values(by='percent_2', ascending=True)
# Out:
# debt                   0    1  percent_2
# family_status
# widow / widower      896   63   6.569343
# divorced            1110   85   7.112971
# married            11408  931   7.545182
# civil partnership   3763  388   9.347145
# unmarried           2536  274   9.750890

# %% [markdown]
# **Conclusão**
#
# Clientes de todos os tipos de status familiar apresentaram de inadimplência entre 6,57 (viúvos e viúvas) a 9,75% (solteiros).

# %% [markdown]
# **Existe uma correlação entre o status familiar e o pagamento em dia?**

# %%
pivot_table_family_status = cse.pivot_table(index = 'total_income', columns='debt', values='dob_years', aggfunc='count')
pivot_table_family_status

pivot_table_family_status['percent_3'] = pivot_table_family_status[1] / (pivot_table_family_status[1]+ pivot_table_family_status[0]) * 100
pivot_table_family_status.sort_values(by='percent_3', ascending=True).head(15)
# Out:
# debt              0     1  percent_3
# total_income
# 29973.6640     26.0   1.0   3.703704
# 32675.8355    161.0   8.0   4.733728
# 26063.4715    347.0  18.0   4.931507
# 22836.0820     41.0   3.0   6.818182
# 20101.2700    923.0  77.0   7.700000
# 25435.5815    419.0  61.0  12.708333
# 17223.9615     13.0   2.0  13.333333
# 21204.0860      6.0   1.0  14.285714
# 3306.7620       NaN   1.0        NaN
# 3392.8450       1.0   NaN        NaN
# 3418.8240       1.0   NaN        NaN
# 3471.2160       1.0   NaN        NaN
# 3503.2980       1.0   NaN        NaN
# 3595.6410       1.0   NaN        NaN
# 3815.1530       1.0   NaN        NaN

# %% [markdown]
# **Conclusão**
#
# Não foi evidenciado padrão de acordo com a faixa de renda e status familiar

# %% [markdown]
# **Como a finalidade do crédito afeta a taxa de inadimplência?**

# %%
for index, row in cse.iterrows():
    if isinstance(row['purpose'], str) and 'education' in row['purpose'] or 'educated' in row['purpose'] or 'university' in row['purpose']:
        cse.at[index, 'purpose_categoria'] = 'education'
    elif isinstance(row['purpose'], str) and ('car' in row['purpose'] or 'cars' in row['purpose']):
        cse.at[index, 'purpose_categoria'] = 'cars'
    elif isinstance(row['purpose'], str) and 'wedding' in row['purpose']:
        cse.at[index, 'purpose_categoria'] = 'wedding'
    elif isinstance(row['purpose'], str) and ('house' in row['purpose'] or 'housing' in row['purpose'] or'property' in row['purpose'] or 'real estate' in row['purpose']):
        cse.at[index, 'purpose_categoria'] = 'house'

print(cse['purpose_categoria'])
print(cse.info())
print(cse.head(15))
# Out:
# 0            house
# 1             cars
# 2            house
# 3        education
# 4          wedding
#            ...
# 21520        house
# 21521         cars
# 21522        house
# 21523         cars
# 21524         cars
# Name: purpose_categoria, Length: 21454, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21454 entries, 0 to 21524
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   children           21454 non-null  int64
#  1   days_employed      21454 non-null  float64
#  2   dob_years          21454 non-null  float64
#  3   education          21454 non-null  object
#  4   education_id       21454 non-null  int64
#  5   family_status      21454 non-null  object
#  6   family_status_id   21454 non-null  int64
#  7   gender             21454 non-null  object
#  8   income_type        21454 non-null  object
#  9   debt               21454 non-null  int64
#  10  total_income       21454 non-null  float64
#  11  purpose            21454 non-null  object
#  12  age_category       21454 non-null  object
#  13  purpose_categoria  21454 non-null  object
#  14  cat_dob_years      21454 non-null  float64
#  15  cat_children       21454 non-null  object
#  16  cat_total_income   21454 non-null  object
# dtypes: float64(4), int64(4), object(9)
# memory usage: 3.5+ MB
# None
#     children  days_employed  dob_years            education  education_id  \
# 0          1    8437.673028       42.0    bachelor's degree             0
# 1          1    4024.803754       36.0  secondary education             1
# 2          0    5623.422610       33.0  secondary education             1
# 3          3    4124.747207       32.0  secondary education             1
# 4          0   66914.728907       53.0  secondary education             1
# 5          0     926.185831       27.0    bachelor's degree             0
# 6          0    2879.202052       43.0    bachelor's degree             0
# 7          0     152.779569       50.0  secondary education             1
# 8          2    6929.865299       35.0    bachelor's degree             0
# 9          0    2188.756445       41.0  secondary education             1
# 10         2    4171.483647       36.0    bachelor's degree             0
# 11         0     792.701887       40.0  secondary education             1
# 12         0   44256.003683       65.0  secondary education             1
# 13         0    1846.641941       54.0         some college             2
# 14         0    1844.956182       56.0    bachelor's degree             0
#
#         family_status  family_status_id gender income_type  debt  \
# 0             married                 0      F    employee     0
# 1             married                 0      F    employee     0
# 2             married                 0      M    employee     0
# 3             married                 0      M    employee     0
# 4   civil partnership                 1      F     retiree     0
# 5   civil partnership                 1      M    business     0
# 6             married                 0      F    business     0
# 7             married                 0      M    employee     0
# 8   civil partnership                 1      F    employee     0
# 9             married                 0      M    employee     0
# 10            married                 0      M    business     0
# 11            married                 0      F    employee     0
# 12  civil partnership                 1      M     retiree     0
# 13            married                 0      F    employee     0
# 14  civil partnership                 1      F    business     1
#
#     total_income                              purpose age_category  \
# 0     40620.1020                purchase of the house        adult
# 1     17932.8020                         car purchase        adult
# 2     23341.7520                purchase of the house        adult
# 3     42820.5680              supplementary education        adult
# 4     25378.5720                    to have a wedding        adult
# 5     40922.1700                purchase of the house        adult
# 6     38484.1560                 housing transactions        adult
# 7     21731.8290                            education        adult
# 8     15337.0930                     having a wedding        adult
# 9     23108.1500  purchase of the house for my family        adult
# 10    18230.9590                      buy real estate        adult
# 11    12331.0770           buy commercial real estate        adult
# 12    25435.5815                    to have a wedding       eldery
# 13    20873.3170                         car purchase        adult
# 14    26420.4660          buy residential real estate        adult
#
#    purpose_categoria  cat_dob_years  cat_children cat_total_income
# 0              house           42.0   até 1 filho      30 a 50 mil
# 1               cars           36.0   até 1 filho       até 30 mil
# 2              house           33.0   até 1 filho       até 30 mil
# 3          education           32.0  até 3 filhos      30 a 50 mil
# 4            wedding           53.0   até 1 filho       até 30 mil
# 5              house           27.0   até 1 filho      30 a 50 mil
# 6              house           43.0   até 1 filho      30 a 50 mil
# 7          education           50.0   até 1 filho       até 30 mil
# 8            wedding           35.0  até 3 filhos       até 30 mil
# 9              house           41.0   até 1 filho       até 30 mil
# 10             house           36.0  até 3 filhos       até 30 mil
# 11             house           40.0   até 1 filho       até 30 mil
# 12           wedding           65.0   até 1 filho       até 30 mil
# 13              cars           54.0   até 1 filho       até 30 mil
# 14             house           56.0   até 1 filho       até 30 mil

# %%
pivot_table_deb_purpose_cat = cse.pivot_table(columns='purpose_categoria', values='debt', aggfunc='mean')*100
pivot_table_deb_purpose_cat
# Out:
# purpose_categoria      cars  education     house   wedding
# debt               9.359034   9.220035  7.233373  8.003442

# %% [markdown]
# **Conclusão**
#
# A taxa de inadimplência calculada por categoria de motivos para tomada de empréstimo indica:
# 7,23% tomaram crédito para custear compra, aluguel ou melhorias de residência
# 9,36% para compra, venda ou conserto de veículo
# 9,22% para investir em educação
# 8% para fins de casamento
#
# Conclui-se que clientes que tomam crédito para compra, venda ou conserto de veículo apresentam um risco maior de inadimplência, seguidos por educação, casamento e residência.

# %% [markdown]
# # Conclusão Geral
#
# Foram realizadas análise dos dados recebidos, com verificação dos valores ausentes, duplicados ou com erros e distorções. Foram feitos correção dos valores de acordo com média calculada entre gênero, idade, qantidade de filhos, critérios esses escolhidos de acordo com análise por coluna. Removidos também duplicados e corrigidos dados negativos ou incorretos.
#
# De acordo com os cálculos de taxa de inadimplência e hipóteses analisadas, ficou evidenciado que clientes solteiros e com união estável, com 1 a 4 filhos e cujo motivo de tomada de crédito seja  para compra, venda ou conserto de veículo, são os que apresentam maior risco para o banco, de acordo com os parâmetros apresentados.
